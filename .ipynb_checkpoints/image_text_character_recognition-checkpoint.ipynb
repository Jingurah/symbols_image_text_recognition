# %%
import cv2
import pytesseract
import os
import numpy as np

caffemodel_path = "C:/Users/jingu/Downloads/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel"

if os.path.isfile(caffemodel_path):
    print("File exists")
else:
    print("File does not exist")

# Load the image
image = cv2.imread("C:/Users/jingu/downloads/Frk2CrHXsAEQr8P.jpeg")

# Check if the image is loaded properly
if image is None:
    print('Error: Image did not load properly.')
else:
    # Convert the image to grayscale
    grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply thresholding to the image
    thresholded_image = cv2.threshold(grayscale_image, 127, 255, cv2.THRESH_BINARY)[1]

    # Find contours in the image
    contours, hierarchy = cv2.findContours(thresholded_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Find the largest contour in the image
    largest_contour = max(contours, key=cv2.contourArea)

    # Extract the bounding box of the largest contour
    bounding_box = cv2.boundingRect(largest_contour)

    # Extract the coordinates of the bounding box
    top_left_x = bounding_box[0]
    top_left_y = bounding_box[1]
    width = bounding_box[2]
    height = bounding_box[3]

    # Crop the image to the bounding box
    cropped_image = image[top_left_y:top_left_y + height, top_left_x:top_left_x + width]

    # Recognize the text in the cropped image
    text = recognize_text(cropped_image)

    # Recognize the symbols in the cropped image
    symbols = pytesseract.image_to_boxes(cropped_image)

    # Print the recognized text, symbols, and image class
    print("Recognized text:", text)
    #print("Recognized symbols:\n", symbols)

    # Recognize the text in the original image
    original_text = recognize_text(image)

    # Recognize the symbols in the original image
    original_symbols = pytesseract.image_to_boxes(image)

    # Print the recognized text, symbols, and image class
    print("Recognized text in original image:", original_text)
    print("Recognized symbols in original image:\n", original_symbols)
    print("Predicted image class:",  prediction)


def recognize_text(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    recognized_text = pytesseract.image_to_string(gray_image)
    return recognized_text
# Out:
# File exists
# Recognized text: It is semicolon
#
# we will hardly use it.
#
#
# Recognized text in original image: It is semicolon
#
# we will hardly use it.
#
#
# Recognized symbols in original image:
#  I 163 932 182 988 0
# t 181 929 201 987 0
# i 224 928 277 983 0
# s 267 928 277 983 0
# s 313 930 337 971 0
# e 340 932 370 969 0
# m 375 931 422 970 0
# i 427 931 439 981 0
# c 441 932 467 970 0
# o 471 932 504 970 0
# l 511 930 522 988 0
# o 525 932 558 970 0
# n 566 931 596 970 0
# w 61 821 111 860 0
# e 115 821 145 857 0
# i 163 662 494 928 0
# u 533 819 563 858 0
# s 565 817 589 858 0
# e 592 820 621 857 0
# i 661 817 662 873 0
# f 661 817 690 873 0
# . 694 821 703 831 0
# C 17 468 57 519 0
# o 63 468 100 507 0
# m 105 467 171 507 0
# p 173 450 215 506 0
# u 195 450 236 519 0
# t 221 466 264 506 0
# e 267 466 293 514 0
# r 298 466 370 506 0
# S 393 466 428 519 0
# c 434 466 466 506 0
# i 470 467 492 522 0
# e 498 466 531 506 0
# n 535 466 579 506 0
# c 566 466 601 522 0
# ...
